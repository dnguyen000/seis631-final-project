# %%
import requests
from bs4 import BeautifulSoup
import time
import random
import json
import re
from urllib.parse import urljoin, urlparse, parse_qs

# %%
# CONFIG
HEADERS = {
    "User-Agent": "Mozilla/5.0 (compatible; setlist-scraper/1.0; +https://example.com/)",
    # You can add Accept-Language etc. if you prefer.
}
REQUEST_TIMEOUT = 15
SLEEP_RANGE = (1.0, 2.5)  # polite delay between requests
MAX_RETRIES = 3

# Example artist listing (replace as needed)
ARTIST_LISTING_BASE = "https://www.setlist.fm/setlists/billy-strings-73c3fe21.html"
# If you want to restrict to pages 1..N, pass pages=N to crawl_artist

# %%
def get_soup(url, session=None):
    """GET a URL with retries and return BeautifulSoup"""
    session = session or requests.Session()
    for attempt in range(MAX_RETRIES):
        try:
            r = session.get(url, headers=HEADERS, timeout=REQUEST_TIMEOUT)
            r.raise_for_status()
            return BeautifulSoup(r.text, "lxml")
        except requests.RequestException as e:
            wait = 1 + attempt * 2
            print(f"Request failed ({e}), retrying in {wait}s...")
            time.sleep(wait)
    raise RuntimeError(f"Failed to GET {url} after {MAX_RETRIES} attempts")

def polite_sleep():
    time.sleep(random.uniform(*SLEEP_RANGE))

def extract_show_links(listing_soup, base_url):
    """
    Find all show subpage links on a listing page inside elements with
    class 'col-xs-12 setlistPreview vevent' (per your note).
    Returns absolute URLs (unique, in order).
    """
    links = []
    # find containers with the exact class or that include those tokens
    containers = listing_soup.find_all(class_=lambda c: c and 'setlistPreview' in c and 'vevent' in c)
    for c in containers:
        a = c.find("a", href=True)
        if a:
            href = a["href"]
            full = urljoin(base_url, href)
            links.append(full)
    # fallback: find any link under .setlistPreview
    if not links:
        for a in listing_soup.select(".setlistPreview a[href]"):
            links.append(urljoin(base_url, a["href"]))
    # dedupe while preserving order
    seen = set()
    uniq = []
    for u in links:
        if u not in seen:
            uniq.append(u)
            seen.add(u)
    return uniq

import re
from datetime import datetime

def parse_date(soup):
    """
    Try multiple patterns to locate the event date and return in YYYY/MM/dd format.
    """
    date_str = ""
    # 1) <time itemprop="startDate" datetime="..."> or generic <time datetime="...">
    time_tag = soup.find("time", {"itemprop": "startDate"}) or soup.find("time", datetime=True)
    if time_tag and time_tag.has_attr("datetime"):
        date_str = time_tag["datetime"]

    # 2) element with class eventDate or .date
    if not date_str:
        date_el = soup.select_one(".eventDate, .date, .setlistDate")
        if date_el:
            date_str = date_el.get_text(strip=True)

    # Convert the date string to the desired YYYY/MM/dd format
    if date_str:
        # Common setlist.fm formats are YYYY-MM-DD (ISO) or Month DD, YYYY
        try:
            # Attempt to parse YYYY-MM-DD
            dt_obj = datetime.strptime(date_str, "%Y-%m-%d")
        except ValueError:
            try:
                # Attempt to parse Month DD, YYYY (e.g., November 15, 2025)
                dt_obj = datetime.strptime(date_str, "%B %d, %Y")
            except ValueError:
                try:
                    # Attempt to parse MMMddYYYY (e.g., Oct232025) which was in your output
                    dt_obj = datetime.strptime(date_str, "%b%d%Y")
                except ValueError:
                    # If all else fails, return the original string or empty string
                    return date_str

        return dt_obj.strftime("%Y/%m/%d")

    return ""

def expand_location_abbr(abbr):
    """Expands state/country abbreviations to full names."""
    state_map = {
        "NJ": "New Jersey", "NY": "New York", "CA": "California", "TX": "Texas",
        "IL": "Illinois", "PA": "Pennsylvania", "MA": "Massachusetts", # Add more as needed
    }
    continent_map = {
        "USA": "North America", "US": "North America", "CA": "North America", # US, Canada
        "UK": "Europe", "DE": "Europe", "FR": "Europe",
        "AU": "Australia",
    }

    # Check for State
    if abbr in state_map:
        return state_map[abbr], "US" # Assuming state abbr means US

    # Check for Continent (based on country code)
    if abbr in continent_map:
        return abbr, continent_map[abbr]

    return abbr, "Unknown"


def parse_venue_and_location(soup):
    """
    Extract venue, city, state, and country/continent from the setlist page.
    Returns (venue_name, city, state, continent)
    """
    venue_name = ""
    event_city = ""
    event_state = ""
    event_continent = ""

    # 1. Target the specific link structure: <a title="More setlists from Prudential Center, Newark, NJ, USA">
    venue_link = soup.select_one('a[title^="More setlists from"]')

    if venue_link:
        # Get the title attribute text: "More setlists from Prudential Center, Newark, NJ, USA"
        full_location_str = venue_link.get("title").replace("More setlists from ", "").strip()

        # This string usually follows the pattern: Venue Name, City, State/Province, Country/Continent
        parts = [p.strip() for p in full_location_str.split(",")]

        if len(parts) >= 4:
            venue_name = parts[0]
            event_city = parts[1]
            # Use helper function to expand state/country
            state_abbr = parts[2]
            continent_abbr = parts[3]

            expanded_state, _ = expand_location_abbr(state_abbr)
            event_state = expanded_state if expanded_state != state_abbr else state_abbr

            # For continent, we will use the country code for 'eventContinent'
            event_continent = continent_abbr

        elif len(parts) == 3:
            # Handle Venue, City, Country (e.g., "The Venue, London, UK")
            venue_name = parts[0]
            event_city = parts[1]
            event_continent = parts[2]
            event_state = "" # State is empty if not provided

    # 2. Cleanup Venue Name: Remove pre-pended text
    header = soup.select_one("h1")
    if venue_name and header:
        header_text = header.get_text(" ", strip=True)
        # Check if the header contains the venue name and "Setlist at"
        match = re.search(r"Setlist at\s*(.*?)\s*—", header_text, re.I)
        if match:
             # Use the captured group if it looks like a venue name
             venue_name = match.group(1).strip()

    # 3. Fallback: If structured parsing failed, try original parsing method (using .setlistVenue, etc.)
    if not venue_name or not event_city:
         # Fallback to the original implementation's logic (kept for robustness)
         # Note: You need to keep the ORIGINAL implementation of parse_venue_and_location
         # in your script, but modify it to return the venue name and a combined location string
         # (location_string). Then you would parse the location_string here.
         # For simplicity, I'm sticking to the targeted approach above, assuming the <a> tag is present.

         # --- Simplified Fallback ---
         venue_el = soup.select_one(".venue, .venueName, .setlistVenue")
         if venue_el and not venue_name:
             venue_name = venue_el.get_text(" ", strip=True)

         loc_el = soup.select_one(".venueLocation, .city, .location")
         if loc_el and not event_city:
             location_str = loc_el.get_text(" ", strip=True)
             parts = [p.strip() for p in location_str.split(",")]
             if len(parts) >= 1:
                 event_city = parts[0]
             if len(parts) >= 2:
                 # Assume parts[1] is State/Country, need more logic for robust splitting
                 event_continent = parts[-1]


    # Final required return: (venue_name, city, state, continent)
    return venue_name, event_city, event_state, event_continent

def parse_sets(soup):
    sets = []
    current_set = None

    # Target the main song list container using its ID or class
    # We look for the main <ol class="songsList"> inside the content div.
    songs_list = soup.select_one(".setlistContent .songsList")

    if not songs_list:
        print("    [!] Error: Could not find the main '.songsList' container.")
        return []

    # Iterate through all direct children <li> of the songsList (which include headers, songs, and ads)
    for li in songs_list.find_all("li", recursive=False):

        # 1. Identify Set/Encore Header
        # Check for classes 'section' (for Set 1, 2, 3) or 'encore'
        if "section" in li.get("class", []) or "encore" in li.get("class", []):

            # Close the previous set if it had songs
            if current_set and current_set["songs"]:
                sets.append(current_set)

            set_name = li.get_text(" ", strip=True)
            is_encore = "encore" in li.get("class", [])
            set_num = None

            # Extract set number from text like "Set 1:", "Set 2:", etc.
            m = re.search(r"Set\s*(\d+)", set_name, re.I)
            if m:
                set_num = int(m.group(1))

            # Initialize a new set object
            current_set = {
                "setNumber": set_num,
                "encore": is_encore,
                "songs": []
            }
            continue # Move to the next <li>

        # 2. Identify Song Item
        # Check for class 'song' and ensure we have an active set object
        elif "song" in li.get("class", []) and current_set is not None:

            # The cleanest song title is inside the <a> tag with class 'songLabel'
            a_tag = li.select_one(".songLabel")

            if a_tag and a_tag.get_text(strip=True):
                song_text = a_tag.get_text(strip=True)

                # We can also capture the full text (including cover/notes in the li) for context,
                # but the user requested clean song titles, so we use the <a> tag.

                # Cleanup (removed unnecessary regex since we target the clean <a> text)

                if song_text:
                    current_set["songs"].append(song_text)

        # 3. Skip Advertisements and other non-setlist items
        elif "setlistFluidAd" in li.get("class", []):
             continue

    # After the loop, append the last set if it exists and has songs
    if current_set and current_set["songs"]:
        sets.append(current_set)

    # --- Final Normalization ---
    # Assign sequential numbers and ensure Encore flag is correct
    next_set_idx = 1
    for s in sets:
        # Fill in missing set numbers (e.g., if Set 1 was found, but the next was an unnumbered Encore)
        if s["setNumber"] is None:
            s["setNumber"] = next_set_idx
        next_set_idx = max(next_set_idx, s["setNumber"] + 1)

        # Ensure 'encore' flag is only true if the set was identified as such
        # (This is mostly done by the loop, but safety check remains)

    return sets

def parse_show_page(url, session=None):
    """Parse a single show page and return the structured dict"""
    session = session or requests.Session()
    soup = get_soup(url, session=session)
    date = parse_date(soup) # Returns YYYY/MM/dd

    # --- UPDATED LINE ---
    venue, city, state, continent = parse_venue_and_location(soup)
    sets = parse_sets(soup)

    return {
        "date": date,
        "venue": venue,
        "eventCity": city,      # New field
        "eventState": state,    # New field
        "eventContinent": continent, # New field
        "setlist": sets,
        "source": url
    }

def crawl_artist(listing_url, pages=3, session=None):
    """
    Crawl the artist listing pages page=1..pages, extract show links, follow each show link,
    and parse each show into the structured format.
    """
    session = session or requests.Session()
    results = []
    listing_base = listing_url.split("?")[0]
    for p in range(1, pages + 1):
        # page param: first page may or may not require '?page=1' — it works both ways but safe to include '?page=N'
        page_url = f"{listing_base}?page={p}"
        print(f"[+] Fetching listing page: {page_url}")
        listing_soup = get_soup(page_url, session=session)
        show_links = extract_show_links(listing_soup, listing_url)
        print(f"    -> found {len(show_links)} show links on page {p}")
        for show_url in show_links:
            print(f"    [*] Parsing show: {show_url}")
            try:
                show_obj = parse_show_page(show_url, session=session)
                results.append(show_obj)
            except Exception as e:
                print(f"      ! Failed to parse {show_url}: {e}")
            polite_sleep()
        polite_sleep()
    return results

if __name__ == "__main__":
    # Run for pages 1..3 as requested
    s = requests.Session()
    try:
        data = crawl_artist(ARTIST_LISTING_BASE, pages=97, session=s)
    except Exception as e:
        print("Fatal error during crawl:", e)
        data = []

    # Print JSON to stdout (pretty) and save to file
    out_file = "string_cheese_incident_setlists.json"
    with open(out_file, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=2, ensure_ascii=False)

    print(f"\nDone. Extracted {len(data)} shows. Output written to: {out_file}")
# Out:
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=1
#     -> found 10 show links on page 1
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/spirit-of-the-suwannee-music-park-live-oak-fl-b415922.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/spirit-of-the-suwannee-music-park-live-oak-fl-3415923.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/spirit-of-the-suwannee-music-park-live-oak-fl-3415927.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/spirit-of-the-suwannee-music-park-live-oak-fl-1341592d.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/spirit-of-the-suwannee-music-park-live-oak-fl-13415929.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/golden-gate-park-san-francisco-ca-13415921.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/the-fillmore-san-francisco-ca-7b43be80.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/westgate-las-vegas-resort-and-casino-las-vegas-nv-1b40a56c.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/westgate-las-vegas-resort-and-casino-las-vegas-nv-b40a576.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/westgate-las-vegas-resort-and-casino-las-vegas-nv-7b40aaa0.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=2
#     -> found 10 show links on page 2
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/halvorsen-park-eureka-ca-6b43be92.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/britt-festival-pavilion-jacksonville-or-7b43be9c.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/lb-day-amphitheater-salem-or-2b475cb2.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/the-pines-music-park-eau-claire-wi-5b431f7c.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/the-pines-music-park-eau-claire-wi-6b43be9a.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/frederik-meijer-gardens-amphitheater-grand-rapids-mi-359356b.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/evans-amphitheater-cleveland-heights-oh-7b43bea4.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/amphitheater-at-las-colonias-park-grand-junction-co-1344f90d.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/gerald-r-ford-amphitheater-vail-co-635a72bf.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/gerald-r-ford-amphitheater-vail-co-735a72b9.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=3
#     -> found 10 show links on page 3
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/red-rocks-amphitheatre-morrison-co-735a72c5.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/red-rocks-amphitheatre-morrison-co-635a72c7.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/double-jj-ranch-rothbury-mi-5b447fc4.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/double-jj-ranch-rothbury-mi-43447fcb.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/the-andrew-j-brady-music-center-cincinnati-oh-2b5b38b6.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/artpark-amphitheater-lewiston-ny-43446fe7.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/prudential-hall-new-jersey-performing-arts-center-newark-nj-235b4cc3.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/merriweather-post-pavilion-columbia-md-6b5a72c2.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/cheshire-county-fairgrounds-swanzey-nh-635aba8b.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/thompsons-point-portland-me-7b443a38.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=4
#     -> found 10 show links on page 4
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/the-caverns-above-ground-amphitheater-pelham-tn-63458acb.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/the-caverns-above-ground-amphitheater-pelham-tn-7b458abc.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/brown-county-music-center-nashville-in-2b58c496.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/the-factory-chesterfield-mo-735a72cd.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/steelhouse-omaha-omaha-ne-635a72cf.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/rose-music-center-at-the-heights-huber-heights-oh-6b467afe.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/the-amp-ballantyne-charlotte-nc-2b47e4d2.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/red-hat-amphitheater-raleigh-nc-5b47f3e8.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/greenfield-lake-amphitheater-wilmington-nc-7b478e54.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/greenfield-lake-amphitheater-wilmington-nc-63478e57.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=5
#     -> found 10 show links on page 5
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/marquee-theatre-tempe-az-735a72c9.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/the-sound-del-mar-ca-5358ef1d.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/the-sound-del-mar-ca-2358f463.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/wiltern-theatre-los-angeles-ca-5b5e3bd0.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/belly-up-aspen-co-635a72cb.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/belly-up-aspen-co-6b5a72d6.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/belly-up-aspen-co-7b5a72d0.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/tabernacle-atlanta-ga-b5f6dc6.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/tabernacle-atlanta-ga-1b5f6dcc.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/tabernacle-atlanta-ga-b5f6dca.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=6
#     -> found 10 show links on page 6
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/the-salt-shed-chicago-il-3b5d70f4.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2025/the-salt-shed-chicago-il-235d70ef.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/dreams-sapphire-resort-puerto-morelos-mexico-7b458a8c.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/dreams-sapphire-resort-puerto-morelos-mexico-3458547.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/dreams-sapphire-resort-puerto-morelos-mexico-1b45852c.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/capitol-theatre-port-chester-ny-7b511600.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/capitol-theatre-port-chester-ny-7b51160c.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/metropolitan-opera-house-philadelphia-pa-2b5118d6.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/brooklyn-paramount-brooklyn-ny-2351ccb3.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/spirit-of-the-suwannee-music-park-live-oak-fl-6351e603.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=7
#     -> found 10 show links on page 7
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/spirit-of-the-suwannee-music-park-live-oak-fl-1b51d934.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/spirit-of-the-suwannee-music-park-live-oak-fl-b51e9b2.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/pier-six-concert-pavilion-baltimore-md-2b5604ee.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/wonderland-forest-lafayette-ny-6b539282.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/cain-park-cleveland-heights-oh-6b53928e.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/louisville-palace-theatre-louisville-ky-5353034d.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/royal-oak-music-theatre-royal-oak-mi-4b5597d6.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/vibrant-music-hall-waukee-ia-43533b03.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/riverside-theater-milwaukee-wi-43537b2b.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/riverside-theater-milwaukee-wi-7350b21d.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=8
#     -> found 10 show links on page 8
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/arvest-bank-theatre-at-the-midland-kansas-city-mo-2b53d0fa.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/the-criterion-oklahoma-city-ok-5b53d704.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/westgate-las-vegas-resort-and-casino-las-vegas-nv-73538239.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/westgate-las-vegas-resort-and-casino-las-vegas-nv-b538d0a.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/westgate-las-vegas-resort-and-casino-las-vegas-nv-3353a005.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/roaring-camp-felton-ca-5355fb75.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/roaring-camp-felton-ca-5b55fb7c.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/roaring-camp-felton-ca-3355fcd9.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/remlinger-farms-carnation-wa-435aab47.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/mcmenamins-historic-edgefield-manor-troutdale-or-2b55b862.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=9
#     -> found 10 show links on page 9
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/mcmenamins-historic-edgefield-manor-troutdale-or-5b544778.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/mcmenamins-historic-edgefield-manor-troutdale-or-6b54523e.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/red-rocks-amphitheatre-morrison-co-1354f571.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/red-rocks-amphitheatre-morrison-co-3b54dc5c.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/red-rocks-amphitheatre-morrison-co-6b54e24e.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/kettlehouse-amphitheater-bonner-mt-4b576706.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/kettlehouse-amphitheater-bonner-mt-335770ad.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/snow-king-resort-jackson-wy-1b5701b0.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/snow-king-resort-jackson-wy-35701b3.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/red-butte-garden-salt-lake-city-ut-7b571660.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=10
#     -> found 10 show links on page 10
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/double-jj-ranch-rothbury-mi-1357f1f9.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/double-jj-ranch-rothbury-mi-4b57330e.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/beech-mountain-resort-beech-mountain-nc-73573ac9.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/the-caverns-pelham-tn-b56e52e.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/the-caverns-above-ground-amphitheater-pelham-tn-1bab1dd4.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/the-caverns-above-ground-amphitheater-pelham-tn-3ab1dd3.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/three-sisters-park-chillicothe-il-33a8e8a1.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/three-sisters-park-chillicothe-il-23a8e8a3.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/stage-ae-pittsburgh-pa-5ba9235c.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/state-theatre-portland-me-2ba9701e.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=11
#     -> found 10 show links on page 11
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/mgm-music-hall-at-fenway-boston-ma-53a8dfd1.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/hard-rock-live-at-the-etess-arena-atlantic-city-nj-23a9701f.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/ting-pavilion-charlottesville-va-7ba92298.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2024/reveille-peak-ranch-burnet-tx-63ab124b.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/fox-theater-oakland-ca-73affab9.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/fox-theater-oakland-ca-3af81db.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/fox-theater-oakland-ca-13af8939.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/stubbs-bar-b-q-austin-tx-7ba1ae0c.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/stubbs-bar-b-q-austin-tx-1ba18594.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/stubbs-bar-b-q-austin-tx-7ba1ae08.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=12
#     -> found 10 show links on page 12
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/stubbs-bar-b-q-austin-tx-73a0567d.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/spirit-of-the-suwannee-music-park-live-oak-fl-33a07439.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/spirit-of-the-suwannee-music-park-live-oak-fl-2ba018be.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/spirit-of-the-suwannee-music-park-live-oak-fl-3ba018e4.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/spirit-of-the-suwannee-music-park-live-oak-fl-3ba01804.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/ruoff-music-center-noblesville-in-ba3b9de.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/pine-knob-music-theatre-clarkston-mi-5ba2471c.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/olg-stage-at-fallsview-casino-niagara-falls-on-canada-43a2538b.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/rose-music-center-at-the-heights-huber-heights-oh-1ba24950.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/forest-hills-stadium-queens-ny-3ba27810.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=13
#     -> found 10 show links on page 13
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/xfinity-center-mansfield-ma-43a207ef.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/saratoga-performing-arts-center-saratoga-springs-ny-1ba20d34.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/penns-peak-jim-thorpe-pa-53a27f29.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/virginia-credit-union-live-at-richmond-raceway-richmond-va-33a23c71.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/pnc-music-pavilion-charlotte-nc-7ba23e44.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/coastal-credit-union-music-park-at-walnut-creek-raleigh-nc-3a2e18f.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/borealis-theatre-palmer-ak-2ba2948e.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/first-interstate-arena-at-metrapark-billings-mt-23a384af.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/sandy-amphitheater-sandy-city-ut-33a384c5.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/haydens-post-jackson-wy-3ba384b0.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=14
#     -> found 10 show links on page 14
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/ford-amphitheater-nampa-id-23a3849f.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/war-memorial-field-sandpoint-id-73a39215.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/mcmenamins-historic-edgefield-manor-troutdale-or-6ba3920e.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/cuthbert-amphitheater-eugene-or-5ba4cb14.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/hayden-homes-amphitheater-bend-or-6ba4320e.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/red-rocks-amphitheatre-morrison-co-1ba76d64.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/red-rocks-amphitheatre-morrison-co-13a76d6d.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/red-rocks-amphitheatre-morrison-co-ba76d6a.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/dillon-amphitheater-dillon-co-73a71e05.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/dillon-amphitheater-dillon-co-73a71ef9.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=15
#     -> found 10 show links on page 15
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/double-jj-ranch-rothbury-mi-43a667a3.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/double-jj-ranch-rothbury-mi-6ba7a2de.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/cheshire-county-fairgrounds-swanzey-nh-3ba62418.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/town-park-telluride-co-3a63d4f.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/black-oak-ranch-laytonville-ca-6ba6e27a.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/black-oak-ranch-laytonville-ca-63a6e27b.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/black-oak-ranch-laytonville-ca-13a6fde5.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/three-sisters-park-chillicothe-il-53a4e705.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/salvage-station-asheville-nc-33a384d9.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/salvage-station-asheville-nc-23a384e7.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=16
#     -> found 10 show links on page 16
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/salvage-station-asheville-nc-23a40033.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/palace-theatre-st-paul-mn-63b85a33.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/riviera-theatre-chicago-il-4bb803ca.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/riviera-theatre-chicago-il-5bb803d4.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/the-sylvee-madison-wi-6bb80a32.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/riverside-theater-milwaukee-wi-63b80a33.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/mulberry-mountain-ozark-ar-6bb8325e.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/belly-up-aspen-co-73ba3ec1.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/belly-up-aspen-co-43bac733.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/belly-up-aspen-co-7bbad264.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=17
#     -> found 10 show links on page 17
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/pima-county-fairgrounds-tucson-az-13a381fd.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/jewel-paradise-cove-resort-and-spa-runaway-bay-jamaica-3bdf197.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/jewel-paradise-cove-resort-and-spa-runaway-bay-jamaica-1b458500.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/jewel-paradise-cove-resort-and-spa-runaway-bay-jamaica-bbdf1a6.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2023/jewel-paradise-cove-resort-and-spa-runaway-bay-jamaica-63bdfed7.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/mission-ballroom-denver-co-53bc17e9.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/mission-ballroom-denver-co-53bc17dd.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/mission-ballroom-denver-co-13bc1d09.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/spirit-of-the-suwannee-music-park-live-oak-fl-3be2553.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/spirit-of-the-suwannee-music-park-live-oak-fl-1bbe255c.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=18
#     -> found 10 show links on page 18
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/spirit-of-the-suwannee-music-park-live-oak-fl-bbe255e.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/roaring-camp-felton-ca-6bb0066a.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/roaring-camp-felton-ca-73b00669.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/red-rocks-amphitheatre-morrison-co-33b2a059.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/red-rocks-amphitheatre-morrison-co-bb2a5be.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/red-rocks-amphitheatre-morrison-co-3bb2b474.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/dillon-amphitheater-dillon-co-2bb2b472.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/dillon-amphitheater-dillon-co-23b2b47f.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/double-jj-ranch-rothbury-mi-1bb5916c.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/double-jj-ranch-rothbury-mi-7bb596dc.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=19
#     -> found 10 show links on page 19
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/double-jj-ranch-rothbury-mi-1b4585fc.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/black-oak-ranch-laytonville-ca-43b4238f.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/black-oak-ranch-laytonville-ca-1bb42960.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/black-oak-ranch-laytonville-ca-53b43709.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/harmony-park-music-garden-clarks-grove-mn-1b4585f4.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/harmony-park-music-garden-clarks-grove-mn-1b4585dc.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/harmony-park-music-garden-clarks-grove-mn-b4585ca.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/faubourg-brewing-company-new-orleans-la-6bb78ae2.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/faubourg-brewing-company-new-orleans-la-43b7937b.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/the-eastern-atlanta-ga-53b64fa1.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=20
#     -> found 10 show links on page 20
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/centennial-olympic-park-atlanta-ga-7bb656e8.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/centennial-olympic-park-atlanta-ga-6bb656ea.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/greenfield-lake-amphitheater-wilmington-nc-43a317c3.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/greenfield-lake-amphitheater-wilmington-nc-6347d2a7.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/salvage-station-asheville-nc-73bdb6c5.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/salvage-station-asheville-nc-63bdb6c7.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/salvage-station-asheville-nc-6bbdb6ce.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/ting-pavilion-charlottesville-va-4bb60bce.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/private-venue-boulder-co-2389a403.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/jewel-paradise-cove-resort-and-spa-runaway-bay-jamaica-345859b.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=21
#     -> found 10 show links on page 21
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/jewel-paradise-cove-resort-and-spa-runaway-bay-jamaica-3458593.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/jewel-paradise-cove-resort-and-spa-runaway-bay-jamaica-3458597.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/jewel-paradise-cove-resort-and-spa-runaway-bay-jamaica-388edbb.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/jewel-paradise-cove-resort-and-spa-runaway-bay-jamaica-1b88edc4.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/jewel-paradise-cove-resort-and-spa-runaway-bay-jamaica-388edc7.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2022/auditorium-theatre-chicago-il-738b6625.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/auditorium-theatre-chicago-il-2b8b68f2.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/auditorium-theatre-chicago-il-538b6f45.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/boulder-theater-boulder-co-4343afe7.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/mission-ballroom-denver-co-4b8b87fe.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=22
#     -> found 10 show links on page 22
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/mission-ballroom-denver-co-538b87f9.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/mission-ballroom-denver-co-6b8a4a2a.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/stubbs-bar-b-q-austin-tx-6b8afa5a.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/stubbs-bar-b-q-austin-tx-638afa5b.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/stubbs-bar-b-q-austin-tx-738afa65.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/spirit-of-the-suwannee-music-park-live-oak-fl-538a8bc1.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/spirit-of-the-suwannee-music-park-live-oak-fl-4b8a8bc2.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/spirit-of-the-suwannee-music-park-live-oak-fl-438a8bc3.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/william-randolph-hearst-greek-theatre-berkeley-ca-2b8f74f2.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/william-randolph-hearst-greek-theatre-berkeley-ca-1b8f7584.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=23
#     -> found 10 show links on page 23
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/red-rocks-amphitheatre-morrison-co-338fe091.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/red-rocks-amphitheatre-morrison-co-4b8febe6.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/red-rocks-amphitheatre-morrison-co-4b8feb4e.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/dillon-amphitheater-dillon-co-3b8fe4dc.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/dillon-amphitheater-dillon-co-5b8fe71c.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2021/montage-mountain-scranton-pa-7b8faa14.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2020/festival-venue-unknown-city-6b825e5e.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2020/private-venue-denver-co-6b871eaa.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/mission-ballroom-denver-co-5b9a07ac.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/mission-ballroom-denver-co-239a0c17.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=24
#     -> found 10 show links on page 24
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/auditorium-theatre-chicago-il-1b9d4968.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/auditorium-theatre-chicago-il-139d4969.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/auditorium-theatre-chicago-il-139d4971.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/stubbs-bar-b-q-austin-tx-339d788d.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/stubbs-bar-b-q-austin-tx-239d7883.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/stubbs-bar-b-q-austin-tx-3b9d7880.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/spirit-of-the-suwannee-music-park-live-oak-fl-2b9dc066.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/spirit-of-the-suwannee-music-park-live-oak-fl-1b9dc93c.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/spirit-of-the-suwannee-music-park-live-oak-fl-5b9dd300.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/fox-theater-oakland-ca-439c672b.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=25
#     -> found 10 show links on page 25
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/fox-theater-oakland-ca-3b9c6cf8.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/the-fillmore-san-francisco-ca-6b9c76ee.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/the-fillmore-san-francisco-ca-4b9c7f8a.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/cuthbert-amphitheater-eugene-or-739c16cd.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/cuthbert-amphitheater-eugene-or-439c1b97.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/cuthbert-amphitheater-eugene-or-5b9c1b90.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/blue-cow-pavilion-floyd-va-639e0257.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/montage-mountain-scranton-pa-3b9e0c24.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/montage-mountain-scranton-pa-239e141b.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/red-rocks-amphitheatre-morrison-co-2b9e1cf6.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=26
#     -> found 10 show links on page 26
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/red-rocks-amphitheatre-morrison-co-239e1cf7.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/red-rocks-amphitheatre-morrison-co-339e1cf1.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/dillon-amphitheater-dillon-co-39edd13.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/dillon-amphitheater-dillon-co-6b9eeaaa.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/fox-theatre-atlanta-ga-5b9e9b4c.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/fox-theatre-atlanta-ga-7385aa65.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/iroquois-amphitheater-louisville-ky-7b85aa64.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/iroquois-amphitheater-louisville-ky-7385aa59.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/double-jj-ranch-rothbury-mi-4385df3b.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/double-jj-ranch-rothbury-mi-4b85df3a.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=27
#     -> found 10 show links on page 27
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/double-jj-ranch-rothbury-mi-5b85df38.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/capitol-theatre-port-chester-ny-6b919e66.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/capitol-theatre-port-chester-ny-53905765.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/capitol-theatre-port-chester-ny-b905df2.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/allegany-county-fairgrounds-cumberland-md-1b907910.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/allegany-county-fairgrounds-cumberland-md-13907911.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/mardi-gras-world-new-orleans-la-5b85df40.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/mardi-gras-world-new-orleans-la-4390838b.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/orpheum-theater-new-orleans-la-4385df47.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/the-fabulous-fox-theatre-st-louis-mo-73934eed.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=28
#     -> found 10 show links on page 28
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/the-fabulous-fox-theatre-st-louis-mo-1b9349cc.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/buttermilk-aspen-co-7393e2dd.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/buttermilk-aspen-co-5393ebcd.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/belly-up-aspen-co-3b93ec8c.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/montbleu-theatre-stateline-nv-5385df3d.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/montbleu-theatre-stateline-nv-5b85df3c.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/montbleu-theatre-stateline-nv-4385df33.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/the-chelsea-las-vegas-nv-4392b763.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/the-chelsea-las-vegas-nv-7b955a80.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/the-chelsea-las-vegas-nv-2b9554ea.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=29
#     -> found 10 show links on page 29
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/jewel-paradise-cove-resort-and-spa-runaway-bay-jamaica-4395873b.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/jewel-paradise-cove-resort-and-spa-runaway-bay-jamaica-3958dc7.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/jewel-paradise-cove-resort-and-spa-runaway-bay-jamaica-13958dcd.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2019/jewel-paradise-cove-resort-and-spa-runaway-bay-jamaica-63959267.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/1st-bank-center-broomfield-co-1b9475a8.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/1st-bank-center-broomfield-co-2b942c2a.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/1st-bank-center-broomfield-co-3b942c34.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/the-palladium-worcester-ma-5b9baf00.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/the-palladium-worcester-ma-4b98efaa.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/the-fillmore-philadelphia-philadelphia-pa-6b96520e.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=30
#     -> found 10 show links on page 30
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/the-fillmore-philadelphia-philadelphia-pa-7396521d.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/spirit-of-the-suwannee-music-park-live-oak-fl-13966185.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/spirit-of-the-suwannee-music-park-live-oak-fl-13966181.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/spirit-of-the-suwannee-music-park-live-oak-fl-b96619e.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/mountain-sun-pub-and-brewery-boulder-co-43e98f5b.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/mountain-sun-pub-and-brewery-boulder-co-5be98f64.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/planet-bluegrass-lyons-co-3382943d.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/carson-creek-ranch-austin-tx-43e9b303.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/carson-creek-ranch-austin-tx-43e9b30f.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/carson-creek-ranch-austin-tx-43e9b7c3.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=31
#     -> found 10 show links on page 31
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/red-rocks-amphitheatre-morrison-co-33ebd809.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/red-rocks-amphitheatre-morrison-co-73ebe679.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/red-rocks-amphitheatre-morrison-co-1bebed54.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/dillon-amphitheater-dillon-co-639e6a33.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/dillon-amphitheater-dillon-co-739e6a3d.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/town-park-telluride-co-23eb948f.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/town-park-telluride-co-1beba528.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/cuthbert-amphitheater-eugene-or-6b85dec6.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/cuthbert-amphitheater-eugene-or-6385dec7.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/plumas-sierra-county-fairgrounds-quincy-ca-3ea5d03.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=32
#     -> found 10 show links on page 32
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/plumas-sierra-county-fairgrounds-quincy-ca-7385dec1.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/double-jj-ranch-rothbury-mi-4bea63d2.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/double-jj-ranch-rothbury-mi-53ea6325.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/double-jj-ranch-rothbury-mi-73ea72c9.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/double-jj-ranch-rothbury-mi-bea6d72.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/us-cellular-center-asheville-nc-39745c3.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/centennial-olympic-park-atlanta-ga-3bec28e4.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2018/variety-playhouse-atlanta-ga-5bec1f94.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2017/capitol-theatre-port-chester-ny-53e1d3e1.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/2017/capitol-theatre-port-chester-ny-7be1da64.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=33
#     -> found 10 show links on page 33
# ...
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/zephyr-club-salt-lake-city-ut-1b85edf0.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/stoddards-brewhouse-and-eatery-sunnyvale-ca-385edf3.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/santa-rosa-brewing-company-santa-rosa-ca-1385edf1.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/sweetwater-music-hall-mill-valley-ca-1b85edfc.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/alpine-meadows-ski-resort-alpine-meadows-ca-1385edfd.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=185
#     -> found 10 show links on page 185
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/bluewater-brew-co-south-lake-tahoe-ca-b85edfe.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/alpine-meadows-ski-resort-alpine-meadows-ca-5bcfff84.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/bluewater-brew-co-south-lake-tahoe-ca-385edff.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/the-cozy-park-city-ut-1b85edf8.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/the-cozy-park-city-ut-1385edf9.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/one-world-cafe-telluride-co-b85edfa.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/club-rio-moab-ut-385edfb.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/club-rio-moab-ut-1b85ed04.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/the-forest-queen-crested-butte-co-5bcfff80.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/center-for-the-arts-crested-butte-co-1385ed05.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=186
#     -> found 10 show links on page 186
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/old-martinas-hall-ranchos-de-taos-nm-b85ed06.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/trails-end-vail-co-385ed07.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/double-diamond-aspen-co-1b85ed00.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/corona-street-grill-dillon-co-1385ed01.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/the-forest-queen-crested-butte-co-b85ed02.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/the-forest-queen-crested-butte-co-385ed03.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/alligator-lounge-breckenridge-co-1385ed0d.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/alligator-lounge-breckenridge-co-b85ed0e.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/one-world-cafe-telluride-co-385ed0f.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/club-rio-moab-ut-1b85ed08.html
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=187
#     -> found 10 show links on page 187
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/club-rio-moab-ut-1385ed09.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/the-cozy-park-city-ut-b85ed0a.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/alpine-meadows-ski-resort-alpine-meadows-ca-385ed0b.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/alpine-meadows-ski-resort-alpine-meadows-ca-1b85ed14.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/bluewater-brew-co-south-lake-tahoe-ca-1385ed15.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/bluewater-brew-co-south-lake-tahoe-ca-b85ed16.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/the-cozy-park-city-ut-1385ed71.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/the-cozy-park-city-ut-1b85ed70.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/mangy-moose-teton-village-wy-385ed73.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/the-trap-bar-and-grill-alta-wy-b85ed7e.html
#     [!] Error: Could not find the main '.songsList' container.
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=188
#     -> found 10 show links on page 188
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/the-trap-bar-and-grill-alta-wy-1385ed7d.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/the-trap-bar-and-grill-alta-wy-1b85ed7c.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/trails-end-vail-co-1b85ed78.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/corona-street-grill-dillon-co-b85ed7a.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/the-forest-queen-crested-butte-co-385ed7b.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/the-forest-queen-crested-butte-co-7b85f284.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/one-world-cafe-telluride-co-7385f285.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/one-world-cafe-telluride-co-6b85f286.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/manhattans-colorado-springs-co-6385f287.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/alligator-lounge-breckenridge-co-7385f281.html
#     [!] Error: Could not find the main '.songsList' container.
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=189
#     -> found 10 show links on page 189
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/the-slope-winter-park-co-6b85f282.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/double-diamond-aspen-co-6385f283.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/kikapoo-lounge-keystone-co-4b9d8fba.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/kikapoo-lounge-keystone-co-7b85f28c.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/boulder-theater-boulder-co-7385f28d.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/double-diamond-aspen-co-6b85f28e.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/fox-theatre-boulder-co-6385f28f.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1996/double-diamond-aspen-co-6b85f28a.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/one-world-cafe-telluride-co-6b85f296.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/mountain-sun-pub-and-brewery-boulder-co-6385f297.html
#     [!] Error: Could not find the main '.songsList' container.
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=190
#     -> found 10 show links on page 190
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/hermans-hideaway-denver-co-7b85f290.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/the-forest-queen-crested-butte-co-7385f291.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/double-diamond-aspen-co-6b85f292.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/mountain-sun-pub-and-brewery-boulder-co-43f2576f.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/tungsten-grill-nederland-co-6bc0d6ee.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/sudwerk-brewing-company-dock-store-davis-ca-6385f293.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/private-venue-yosemite-national-park-ca-6b85f29e.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/bluewater-brew-co-south-lake-tahoe-ca-7b85f298.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/stoddards-brewhouse-and-eatery-sunnyvale-ca-7385f299.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/stanford-university-stanford-ca-6b85f29a.html
#     [!] Error: Could not find the main '.songsList' container.
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=191
#     -> found 10 show links on page 191
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/bluebird-theater-denver-co-6385f29b.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/town-park-telluride-co-7b85f2a4.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/private-venue-dolores-co-7385f2ad.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/mountain-sun-pub-and-brewery-boulder-co-7385f2a9.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/mountain-sun-pub-and-brewery-boulder-co-6385f2ab.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/mountain-sun-pub-and-brewery-boulder-co-7b85f2b4.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/club-rio-moab-ut-7bc0d6f4.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/zephyr-club-salt-lake-city-ut-6385f2b3.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/private-venue-santa-cruz-ca-7b85f2b0.html
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1995/mountain-sun-pub-and-brewery-boulder-co-6b85f2b6.html
#     [!] Error: Could not find the main '.songsList' container.
# [+] Fetching listing page: https://www.setlist.fm/setlists/the-string-cheese-incident-13d6ade1.html?page=192
#     -> found 6 show links on page 192
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1994/the-depot-telluride-co-7b85f2c4.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1994/fly-me-to-the-moon-saloon-telluride-co-7385f2bd.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1994/mountain-sun-pub-and-brewery-boulder-co-6b85f2be.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1994/main-street-telluride-co-6385f2bf.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1994/town-park-telluride-co-6b85f2ba.html
#     [!] Error: Could not find the main '.songsList' container.
#     [*] Parsing show: https://www.setlist.fm/setlist/the-string-cheese-incident/1993/the-depot-telluride-co-6b85f2c6.html
#     [!] Error: Could not find the main '.songsList' container.
#
# Done. Extracted 1916 shows. Output written to: string_cheese_incident_setlists.json
